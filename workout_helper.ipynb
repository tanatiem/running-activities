# %%
import pandas as pd
import numpy as np
from datetime import timedelta

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.preprocessing import scale

import warnings
warnings.filterwarnings('ignore')

# %%
filename = 'datasets/Activities.csv'

# All columns
# cols = ['Activity Type', 'Date', 'Title', 'Distance', 'Calories',
#        'Time', 'Avg HR', 'Max HR', 'Aerobic TE', 'Avg Run Cadence',
#        'Max Run Cadence', 'Avg Pace', 'Best Pace', 'Elev Gain', 'Elev Loss',
#        'Avg Stride Length', 'Avg Vertical Ratio', 'Avg Vertical Oscillation',
#        'Avg Ground Contact Time', 'Avg GCT Balance']

cols = ['Activity Type', 'Date', 'Title', 'Distance', 'Calories',
       'Time', 'Avg HR', 'Avg Run Cadence', 'Avg Pace']

colnames = ['type', 'date', 'title', 'distance', 'calories',
       'time', 'avg_hr', 'avg_cadence', 'avg_pace']

df = pd.read_csv(filename, parse_dates=['Date'], usecols=cols,
                na_values='--', thousands=',')
df.columns = colnames

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 9 columns):
# type           705 non-null object
# date           705 non-null datetime64[ns]
# title          705 non-null object
# distance       705 non-null float64
# calories       686 non-null float64
# time           705 non-null object
# avg_hr         687 non-null float64
# avg_cadence    593 non-null float64
# avg_pace       693 non-null object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 49.6+ KB

# %%
df = df[['type','title','date','distance','time']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 5 columns):
# type        705 non-null object
# title       705 non-null object
# date        705 non-null datetime64[ns]
# distance    705 non-null float64
# time        705 non-null object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 27.6+ KB

# %%
df['type'].value_counts()
# Out:
# running              560
# indoor_cycling        60
# treadmill_running     46
# cycling               24
# walking                8
# elliptical             4
# other                  3
# Name: type, dtype: int64

# %%
df.title = df.title.str.lower()

df['easy'] = df.title.str.contains('easy')
df['tempo'] = df.title.str.contains('tempo')
df['interval'] = df.title.str.contains('interval')
df['long'] = np.logical_or(df.title.str.contains('long'), df.distance >= 13)
df['recovery'] = df.title.str.contains('recover')

def categorize_run(x):
    cat = ''
    if x['tempo']:
        cat = 'tempo'
    elif x['interval']:
        cat = 'interval'
    elif x['recovery']:
        cat = 'recovery'
    elif x['long']:
        cat = 'long'
    elif x['easy']:
        cat = 'easy'
    return cat

df['category'] = df.apply(categorize_run, axis=1)
df
# Out:
#                   type                                    title  \
# 0              running                      easy run after sick
# 1              running                            lat phrao run
# 2              running                            lat phrao run
# 3    treadmill_running                                treadmill
# 4    treadmill_running                                treadmill
# 5    treadmill_running                                treadmill
# 6              running                            lat phrao run
# 7              running                                 easy run
# 8              running                            chatuchak run
# 9              running                         1600x2 800x2 run
# 10             running                            lat phrao run
# 11      indoor_cycling                              bike indoor
# 12             running                                tempo run
# 13             running                        interval 6 x 400m
# 14             running                           interval 400x7
# 15             running                            easy long run
# 16             running                                lthr test
# 17      indoor_cycling                              bike indoor
# 18             running                             recovery run
# 19             running                            cuca run 2018
# 20             running                  easy run with test pace
# 21             running                           interval 400x6
# 22      indoor_cycling                              bike indoor
# 23             running                         long run (taper)
# 24             running                               easy tempo
# 25             running                            lat phrao run
# 26             running                            lat phrao run
# 27             running                                 long run
# 28      indoor_cycling              bike / replace tempo run 8k
# 29             running                     interval 1.6k x3 run
# ..                 ...                                      ...
# 675            running                          lumpini running
# 676            running           out of energy running to 10km.
# 677            running  lumpini cadence training / long running
# 678            running                 cadence training running
# 679            running                        lumpini park 5km.
# 680            running                lumpini park 5km. running
# 681            running                 suan luang rama9 running
# 682            running                        slow pace 2.5 km.
# 683            running                          fast pace 5 km.
# 684            running               lumpini first 15km running
# 685            running                   bang rak uncategorized
# 686            running                    bang su uncategorized
# 687            running                    bang su uncategorized
# 688            cycling                         bang bon cycling
# 689            running                    bang su uncategorized
# 690            running                   pak kret uncategorized
# 691            running                   bang rak uncategorized
# 692            running                   bang rak uncategorized
# 693            running               phra khanong uncategorized
# 694            running                    bang su uncategorized
# 695            running                   bang rak uncategorized
# 696            running                    bang su uncategorized
# 697            running                    bang su uncategorized
# 698            running                   bang rak uncategorized
# 699            running               phra khanong uncategorized
# 700            running                    bang su uncategorized
# 701            running                    bang su uncategorized
# 702            running               phra khanong uncategorized
# 703            running               phra khanong uncategorized
# 704            running               phra khanong uncategorized
#
#                    date  distance     time   easy  tempo  interval   long  \
# 0   2018-10-12 21:10:12      5.04    34:49   True  False     False  False
# 1   2018-10-09 23:21:25      5.09    31:26  False  False     False  False
# 2   2018-10-07 22:21:38     11.01  1:08:30  False  False     False  False
# 3   2018-10-06 21:24:32      2.40    30:38  False  False     False  False
# 4   2018-10-05 21:01:16      5.07    32:19  False  False     False  False
# 5   2018-10-04 20:51:56      3.13    30:26  False  False     False  False
# 6   2018-10-03 20:25:54      7.85    43:03  False  False     False  False
# 7   2018-10-02 20:05:12      5.04    32:14   True  False     False  False
# 8   2018-09-30 16:08:15      4.76    29:16  False  False     False  False
# 9   2018-09-26 20:50:53      6.80    37:35  False  False     False  False
# 10  2018-09-25 20:38:42      5.20    32:03  False  False     False  False
# 11  2018-09-24 16:10:28     25.54  1:01:36  False  False     False   True
# 12  2018-09-21 17:47:33      7.31    41:09  False   True     False  False
# 13  2018-09-19 20:31:51      6.93    45:24  False  False      True  False
# 14  2018-09-18 20:40:48      7.48    44:50  False  False      True  False
# 15  2018-09-16 17:16:38     12.06  1:23:32   True  False     False   True
# 16  2018-09-14 20:37:24      5.04    31:48  False  False     False  False
# 17  2018-09-14 00:10:00     13.51    30:50  False  False     False  False
# 18  2018-09-11 18:13:33      4.01    32:37  False  False     False  False
# 19  2018-09-09 05:00:03     10.05    48:06  False  False     False  False
# 20  2018-09-07 21:44:56      5.37    31:07   True  False     False  False
# 21  2018-09-05 20:19:02      6.85    38:43  False  False      True  False
# 22  2018-09-04 22:25:00     20.05    40:29  False  False     False   True
# 23  2018-09-02 17:21:32     12.51  1:21:39  False  False     False   True
# 24  2018-08-31 20:20:33      8.10    45:21   True   True     False  False
# 25  2018-08-29 20:07:49      9.06    52:17  False  False     False  False
# 26  2018-08-28 19:40:35      5.04    29:20  False  False     False  False
# 27  2018-08-26 18:03:48     18.19  2:00:28  False  False     False   True
# 28  2018-08-24 23:31:21     53.30  1:05:17  False   True     False   True
# 29  2018-08-22 22:51:28      8.02    47:11  False  False      True  False
# ..                  ...       ...      ...    ...    ...       ...    ...
# 675 2015-04-03 18:40:11      5.10    27:00  False  False     False  False
# 676 2015-04-01 18:43:38      2.55    16:29  False  False     False  False
# 677 2015-04-01 17:55:56      7.65    41:57  False  False     False   True
# 678 2015-03-29 17:49:21      4.21    40:06  False  False     False  False
# 679 2015-03-27 18:47:39      5.11    26:32  False  False     False  False
# 680 2015-03-20 19:21:40      5.12    25:54  False  False     False  False
# 681 2015-03-17 17:58:00      4.78    38:08  False  False     False  False
# 682 2015-03-16 17:44:53      2.53    17:03  False  False     False  False
# 683 2015-03-16 17:16:16      5.22    27:49  False  False     False  False
# 684 2015-03-13 17:38:21     15.22  1:35:27  False  False     False   True
# 685 2015-03-09 17:00:00      5.17    27:58  False  False     False  False
# 686 2015-03-07 08:15:35     10.26  1:05:16  False  False     False  False
# 687 2015-03-02 13:17:27     10.30  1:03:05  False  False     False  False
# 688 2015-03-01 07:27:18     23.70  2:01:48  False  False     False   True
# 689 2015-02-25 12:52:32     12.88  1:33:48  False  False     False  False
# 690 2015-02-17 17:26:38      3.30    20:11  False  False     False  False
# 691 2015-02-15 06:06:48      7.42    43:27  False  False     False  False
# 692 2015-02-13 17:59:00      5.09    29:24  False  False     False  False
# 693 2015-02-11 17:43:48      4.58    43:09  False  False     False  False
# 694 2015-02-08 18:28:14     10.03  1:09:28  False  False     False  False
# 695 2015-02-06 17:57:45      3.78    33:15  False  False     False  False
# 696 2015-02-04 18:32:25      7.76    59:55  False  False     False  False
# 697 2015-02-02 15:21:28      5.07    37:51  False  False     False  False
# 698 2015-01-30 18:01:57      3.35    20:51  False  False     False  False
# 699 2015-01-28 17:15:13      3.87    39:55  False  False     False  False
# 700 2015-01-24 18:55:35      3.76    25:49  False  False     False  False
# 701 2015-01-20 16:30:23      3.89    24:14  False  False     False  False
# 702 2015-01-14 17:33:31      2.29    22:51  False  False     False  False
# 703 2015-01-11 16:34:46      3.26    31:50  False  False     False  False
# 704 2015-01-07 17:05:16      3.35    34:23  False  False     False  False
#
#      recovery  category
# 0       False      easy
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False      easy
# 8       False
# 9       False
# 10      False
# 11      False      long
# 12      False     tempo
# 13      False  interval
# 14      False  interval
# 15      False      long
# 16      False
# 17      False
# 18       True  recovery
# 19      False
# 20      False      easy
# 21      False  interval
# 22      False      long
# 23      False      long
# 24      False     tempo
# 25      False
# 26      False
# 27      False      long
# 28      False     tempo
# 29      False  interval
# ..        ...       ...
# 675     False
# 676     False
# 677     False      long
# 678     False
# 679     False
# 680     False
# 681     False
# 682     False
# 683     False
# 684     False      long
# 685     False
# 686     False
# 687     False
# 688     False      long
# 689     False
# 690     False
# 691     False
# 692     False
# 693     False
# 694     False
# 695     False
# 696     False
# 697     False
# 698     False
# 699     False
# 700     False
# 701     False
# 702     False
# 703     False
# 704     False
#
# [705 rows x 11 columns]

# %% [markdown]
# ### Export to manually tag running categories

# %%
df.to_csv('output/activity_labels_init.csv', encoding='utf-8')
